# %% [markdown]
# # Interactive Data

# %% [markdown]
# #### David E. Silva, Ph.D

# %% [markdown]
# **This is Bold**<br>
# _This is Italic_

# %% [markdown]
# Things I could Learn from this class:
# * **Understanding of Data Visualization Principles:** Find out about basic guidelines of data visualization and which type of chart to use for what kind of data.
#
# * **Mastery of Visualization Tools**: Get to know the practical application of data visualization tools and applications such as Tableau, Power BI, Matplotlib, Seaborn and Plotly or python.
#
# * **Data Storytelling**: Master the skill of data storytelling by designing data visualization that would communicate insights and trend.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# variable assignment
a=90
print(a)
# Out:
# 90

# %%
#for loop
arr=["priya","chandana","kodeti"]
for i in arr:
    print(i)
# Out:
# priya
# chandana
# kodeti

# %%
# a function with a print statement
y="Priya"
def hey(y):
    print("hey "+ y +" ,How you Doing?")

# %%
hey(y)
# Out:
# hey Priya ,How you Doing?

# %%
# a function with a return statement
y="Priya"
def heywithreturn(y):
    
    s="hey "+ y +" ,How you Doing?"
    return s
heywithreturn(y)
# Out:
# 'hey Priya ,How you Doing?'
